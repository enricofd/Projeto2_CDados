# %% [markdown]
# # Projeto 2 - Ciência dos Dados

# %% [markdown]
# Nome: Felipe Junqueira
#
# Nome: Henridog

# %% [markdown]
# Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# # Classificador automático de sentimento

# %% [markdown]
# ## Preparando o ambiente no jupyter:

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle

# %% [markdown]
# ___
# ## Autenticando no  Twitter
#
# * Conta: @fesi_6000

# %%
#Dados de autenticação do twitter:

#Coloque aqui o identificador da conta no twitter: @fulano

#leitura do arquivo no formato JSON
with open('auth.pass') as fp:    
    data = json.load(fp)

#Configurando a biblioteca. Não modificar
auth = tweepy.OAuthHandler(data['consumer_key'], data['consumer_secret'])
auth.set_access_token(data['access_token'], data['access_token_secret'])

# %% [markdown]
# ___
# ## Etapas do projeto:

# %% [markdown]
# ### Escolha de um produto e coleta das mensagens

# %%
#Produto escolhido:
produto = 'Tesla'

#Quantidade mínima de mensagens capturadas:
n = 500
#Quantidade mínima de mensagens para a base de treinamento:
t = 450

#Filtro de língua, escolha uma na tabela ISO 639-1.
lang = 'en'

# %% [markdown]
# Capturando os dados do twitter:

# %%
#Cria um objeto para a captura

api = tweepy.API(auth)
msgs = []
msg_final=[]

#Inicia a captura, para mais detalhes: ver a documentação do tweepy

for msg in tweepy.Cursor(api.search, q=produto, lang=lang).items():  
    msgs.append(msg.text.lower())
    if len(msgs) > 1501:
        break
msg_final = set(msgs)


Final = []
i = 0
for e in msg_final:
    Final.append(e)
    if len (Final) => 750:
        break

shuffle(Final)
print (len(Final))
# Out:
# 1013
# 751

# %% [markdown]
# Salvando os dados em uma planilha Excel:

# %%
#Verifica se o arquivo não existe para não substituir um conjunto pronto
if not os.path.isfile('./{0}.xlsx'.format(produto)):
    
    #Abre o arquivo para escrita
    writer = pd.ExcelWriter('{0}.xlsx'.format(produto))

    #divide o conjunto de mensagens em duas planilhas
    dft = pd.DataFrame({'Treinamento' : pd.Series(Final[:t])})
    dft.to_excel(excel_writer = writer, sheet_name = 'Treinamento', index = False)

    dfc = pd.DataFrame({'Teste' : pd.Series(Final[t:])})
    dfc.to_excel(excel_writer = writer, sheet_name = 'Teste', index = False)

    #fecha o arquivo
    writer.save()

# %%
# Out:
# ['@tesla_truth nice strobe light in the background',
#  'rt @worldnewsdotcom: video: us motorist records tesla driver ‘completely asleep’ while driving\n\n#teslacar #selfdriving #massachusettsturnpi…',
#  '@tesla_truth next step, you drive your @tesla at home like a game 😎',
#  '@thomasbroadfoot @tesla_truth so a windmill would pay for itself in less than a year.',
#  'i don’t know, if you see someone sleeping in a tesla going down the highway at 60 mph, maybe you should all 911 and… https://t.co/y2volk2gex',
#  '@teslainventory @seanmmitchell @tesla yeah you right erik.',
#  'rt @kaushal316: comparison for gpu utilisation for 1 epoch of training and 1 round of validation using #fastbert.\nseq_length: 128, batch_si…',
#  "@salv_aus @tesla this is so exciting to see people in #australia getting their #model3au's!\n\ncan't wait to get mine!\ncome on #teslabne!",
#  'i love watching either monster electric v gas car races, in this case, a 1/4 mile test against audi e-tron, jaguar… https://t.co/4t6ll0g4ct',
#  'rt @nypost: tesla driver apparently caught sleeping at the wheel going 60 mph https://t.co/rcxppt7clf https://t.co/fpthiv1ufy',
#  'tesla driver sleeps as car speeds along massachusetts highway, video appears to show - https://t.co/ebaasxlg75',
#  '@tonycrisostomo yup lol',
#  'rt @teslaownerssv: tesla has you covered https://t.co/0b9umox8jb',
#  'rt @newsycbot: tesla “open sources” lithium battery advances https://t.co/aj5iqtkixy (cmts https://t.co/b0uk6iefvy)',
#  'rt @vivvchy: tesla powerpack battery project in osaka japan train station https://t.co/b6f0flr1yi',
#  '@mithunoorath @fly4dat @ionity_eu @fastned @temp_worker @tesla more like tesla is retarded for using their own char… https://t.co/ngnmmtn7vl',
#  'omg @tesla riders asleep..\ni could not handle that. ill drive my own car .nope, nope and nope https://t.co/uxtkboshtp',
#  '@insideevs clearly not on auto steer, as indicated by the sound.\n\nhands not on the wheel, busy filming with phone.… https://t.co/q86xdd1ncb',
#  'tesla kicks off construction of phase 2 at gigafactory 3 in shanghai https://t.co/brhqoi0ay9 .....jaws music 🦈 jaws… https://t.co/vuyl8bsnph',
#  '@elonmusk yet customers are called “not credible” ... as many of us are told \n\ntesla customers are neglected, haras… https://t.co/mqc998ujpr',
#  '@karategpa @dakrandall calm down there master roshi. \nlike i said, “anyone who knows how a tesla works”. you have t… https://t.co/kk4xtaoofs',
#  '@samjulien @brandontroberts @tesla @chrisoncode you need it.',
#  'elon musk is a pathological liar who shamefully slandered the hero of the thai cave rescue by calling him a pedophi… https://t.co/m3uvxwxnv0',
#  'rt @nuclear94: another video apparently shows tesla driver, passenger asleep in car https://t.co/stu5r593sl',
#  '@tesla kids playing video games in #model3 ✅\n@elonmusk\n#reykjavik \n#iceland https://t.co/shoqvhqgse',
#  'a lot of triggered people are in the comments section. wearing a pistol holster is fine, as is having your conceale… https://t.co/10fi6z2trh',
#  '@thefive   @jessebwatters the tesla video where the people are sleeping going down the highway   there is a reflect… https://t.co/tr2ydr1bfc',
#  "rt @alterviggo: here's what i love about @vw's id.3 reveal: they are really trying to make ice cars look uncool and outdated while making #…",
#  'tesla stocks are killing my wallet',
#  '@model3owners @tesla any easter eggs in there? @j_fenderson',
#  'rt @vincent13031925: ice-land is now ice-breaking! \n\ntesla is now in #iceland 🎉🎉\n\ncongrats @elonmusk &amp; @tesla team! \n\n$tsla #tesla https://…',
#  'disturbing video shows driver apparently asleep in moving tesla on highway https://t.co/hh7invlq1n via @cbsnews',
#  '@teslamodel3fan @vincent13031925 where i live is standard 24 seven same price but i called my electric company to change it for time of use',
#  'rt @techeblog: volkswagen id.3 revealed, is an all-electric hatchback with a 342-mile range. https://t.co/scpl95pbzm #cars #volkswagen #tes…',
#  'elon musk: tesla, spacex, and the quest for a fantastic future: https://t.co/vvf95dgknr $tsla $scty #tesla #spacex #solarcity',
#  '@qtrresearch @billybernowich @halftimereport @scottwapnercnbc peloton is the tesla of exercise equipment, and tesla… https://t.co/6clvft43fn',
#  'rt @van_essavan: it took china working with tesla less than one year to design and build the gigafactory in shanghai. one year !',
#  '@benshooter 🙋\u200d♀️ is it also take the "tesla owners can schedule service appointments in under a minute, just using… https://t.co/fqz1jygsyk',
#  'rt @thebigkhalifa: if elon musk hit the loud again and start coughing like chief keef in war i will buy a tesla',
#  'catherine o’hara, who’s just netted her first comedy-acting emmy nod, credits a supporting cast of hair pieces: “th… https://t.co/efcovu33hi',
#  'i will own a tesla model s in two years, maybe sooner..',
#  'rt @tammyharrington: that feeling u get when you can drive around and not worry if your tire is gonna pop. thank you @tirestoo \n\n#tesla #re…',
#  'tesla wants people to always be alert with both hands on the wheel in their self-driving cars, but that wasn’t the… https://t.co/sbxije0zvu',
#  'watch tesla drivers apparently asleep at the wheel, renewing autopilot safety questions https://t.co/7x7tjnmipj',
#  'these ppl need to be located 😡\nabsolutely insane!!!\nhttps://t.co/h3htbd9cof',
#  '@tesla tailfins? ❌',
#  '@lesterholtnbc at least that tesla didn’t wreck.',
#  "rt @hamids: let's face it. @jason's criticism of tim cook is dead on. tim cook is to apple what steve ballmer was to microsoft. near-zero i…",
#  '@50k4l @ygteena13 we get it mr tesla',
#  'rt @tesla_truth: believe it or not there are people who watch this and conclude tesla should be banned / recalled \n\nban the bmw. make autop…',
#  "i don't know what i find more disturbing... driving a tesla while asleep or a sleeping speaker of the house.… https://t.co/ydguib6a0h",
#  "@tweetermeyer you'd think that'd be a lot easier with tesla's digital first approach...",
#  'rt @baktesla: @electricfuture5 @dakah3 @austeslaowners @tesla they said australian online store should be up soon',
#  'hollering at these niggas sleeping in the tesla 🤣🤣',
#  'rt @caraganzaus: another week, another video of a tesla driver asleep flying down the highway https://t.co/ebu2j8evkz via @drivetribe @tesl…',
#  '@facts_tesla @zshahan3 @residentsponge all well and good, but what is the recharge speed going to be???',
#  'rt @nbcnews: ford debuts electric mustang suv in direct shot at tesla. https://t.co/ccx47iwodg',
#  'rt @tslaqpodcast: nice to see two different articles out this evening after the market has closed, reiterating things discussed in $tslaq t…',
#  'tesla model s is the quickest safest, most reliable, dedicated all-electric sedan https://t.co/fvrop02w6p',
#  'rt @itshovah: more tesla winner ss https://t.co/hxqbumgjct',
#  '@mosspuppet @brianbrackeen @jason @tesla revolutionized three industries so far',
#  "rt @quodsemper: hey mr. ceo @elonmusk i'll give you a brief summary of your upcoming work commitments:\n- bring #doge to the moon with #spac…",
#  '@elonmusk @tesla set the news straight please. tesla is the future not only for commuters but shipping also. https://t.co/xp9bdlzyoy',
#  '@tesla_truth news from iaa today.. https://t.co/pww5qklt0z',
#  '@phenomenalpoto @jason @elonmusk @tesla this is the whole game for them.... once one emporer is seem to be naked, i… https://t.co/vzxriisiet',
#  '@tesla when coming to turkey?',
#  "@myspivey @brandontroberts @tesla @chrisoncode i don't drive that much these days honestly, i probably don't need i… https://t.co/hseut0v4nt",
#  "rt @nbcla: it's not clear how long the tesla driver and his passenger were asleep for or when they woke up. https://t.co/ufpnqfkvmz https:/…",
#  'rt @alterviggo: "we will come in 2020 with vehicles that can do anything like tesla and are cheaper by half."\n\n--volkswagen brand chief her…',
#  'african giant is really really really good.',
#  '@qldpyrrhonist exactly ... and as long as elon &amp; co. at tesla continue to find a willing standing 69 arrangement in… https://t.co/5kpeyhrukf',
#  "rt @casey: it was parked at a funny angle because 1. i'm a terrible driver and 2. i have to squeeze it in there to fit next to the other te…",
#  '@model3owners @tesla simply, horrible',
#  "if you're 30 and you don't have a tesla yet, you need to re-think your brand",
#  '@fogdo @fuhklanny @tesla very cool! dm me if you want a redeem code for stats for tesla so that you can do stuff wi… https://t.co/tmekdg1io1',
#  'elon musk: tesla pickup truck pushed back to november https://t.co/bhjbicpmoj via @verge #ev #transportation',
#  'will tax payers be putting up all the money then google, and tesla, ect. will take off with all the financial gain ? https://t.co/ugt1jmtpjh',
#  'rt @ninctc: i took a #tesla out for a drive the other day and we managed to get #tradingview up on the screen. buzzing that it drives even…',
#  '@fullychargeddan @evnewsdaily where is 1/2 price of tesla?  $40k @ 1/2 is $20k usd ?  $33k is not 1/2 of model 3 st… https://t.co/mc2hpydfvl',
#  "rt @stevehamel16: this is just too hilarious 🤣🤣🤣\n\ntesla might have just started doubling the size of the factory! \n\ndon't put those drones…",
#  '@zackamen @scot_work @elonmusk @tesla if only elon knew https://t.co/fjo5dzvqnw',
#  'rt @bertelschmitt: @elonmusk deposed in class-action lawsuit over $tsla solarcity merger https://t.co/smidko1fz0 via @bloomberg',
#  "rt @milds72: @brianbrackeen @jason @tesla just imagine @tesla with @apple cash and @apple with @elonmusk imagination. that's a future i wan…",
#  'excite you senses, enjoy life, experience everything in the upmost luxury .... we’re not just a place stay, we are… https://t.co/qobvzmlgki',
#  'rt @ktla: investigators with @ntsb say california officials failed to fix a highway barrier before a tesla crashed into it, killing the dri…',
#  '@alterviggo @tesla @elonmusk i hope they deliver. the planet needs this bad!!!',
#  '@elonmusk except consumers for a month have mentioned the tesla $tsla service app is now missing, with no word from… https://t.co/iy6mwcgufc',
#  '@tesla_truth @kristennetten what....is....happening',
#  '@phenomenalpoto @jason @elonmusk @tesla never get tired of this "oh shit, they can tell that i\'m gorked out of my mind" shifty-eyed gif....',
#  'i just rode in a tesla and i’m in love. 😭',
#  '@letsrebel1 @drcamiloortiz @karpathy @tesla @elonmusk you used $tsla instead of tesla, so you are obviously an inve… https://t.co/e1m6vlswbj',
#  '@tesla_truth i like the wheels.\nhate the overall design. (interior and exterior)',
#  'watch tesla drivers apparently asleep at the wheel, renewing autopilot safety questions https://t.co/1qv3k64bmu https://t.co/e60fvofuvu',
#  '@dethbox @nimbuswolf @vw quarter mile trap speeds:\n\nstinger gt: 106.9 mph\nmodel 3 awd (non-performance): 113.1mph… https://t.co/j3swcdupuz',
#  'https://t.co/6d4xeh3xhw future is&amp;utm_campaign=0ac900e9cd-email_campaign_2019_09_09_06_52',
#  '@tesla_truth i.d.gaf',
#  'rt @cynthiamckinney: battery breakthrough? https://t.co/kmzhpsij29',
#  '@freshjiva bond guys are the smartest in the room 😂😂😂@jimcramer @carlquintanilla',
#  '@cortana_tesla i think that’s fair',
#  '@tesla @elonmusk cost of fsd is $6k in usa and £5.8k in uk ! dont you think thats bit unfair as car prices are same… https://t.co/5zdiviqgef',
#  '@elonmusk deposed in class-action lawsuit over $tsla solarcity merger https://t.co/smidko1fz0 via @bloomberg',
#  "@stevehamel16 @savedtesla @icannot_enough @realchaozhou @tesla oh wow thanks i hadn't realised they were only showi… https://t.co/wjivc3jmtx",
#  'video shows driver apparently asleep in moving tesla on highway https://t.co/o86hpqpoxq',
#  'the amount of tesla’s, jags, range rovers in my city is disgusting',
#  'tesla recuits f1 world champion to challenge porsche taycan nurburgring lap record - https://t.co/upkb1pnpqx',
#  'rt @teslariders: 16th of september is the last day to signup for our #tesla ride &amp; dine event on the 21st through the napa hills. anyone af…',
#  'again...tesla driver caught sleeping behind the wheel on massachusetts turnpike https://t.co/uiwlgttaef',
#  '@mithunoorath @fly4dat @ionity_eu @fastned @temp_worker @tesla tesla is almost a 20 year old company. elon on suicide watch',
#  '@mrnikolatsla @dakrandall adding to what i said, people in a tesla are defiantly more likely to sleep in their car… https://t.co/irni28tqpn',
#  'tesla wants to debut its pickup in november https://t.co/mi8jj6q2pv https://t.co/elqnq9ao0q',
#  'rt @cnbci: watch tesla drivers apparently asleep at the wheel, renewing autopilot safety questions https://t.co/ww7vrctgxu',
#  'took my bf two days but i am convinced a tesla is what i need in my life at some point',
#  'rt @spotted_model: and like clockwork, tsla goes up, and a negative story with no new news (just old + opinion and conjecture) is released…',
#  'driver takes video of \n\nanother driver sleeping \n\nbehind the wheel of a \n\nself-driving tesla \n\nhttps://t.co/r6etw5veu0',
#  'tesla’s future lay not in its ability to produce motor vehicles,\xa0but batteries.\n\nhttps://t.co/ryqe632c12',
#  '@italypete10 @cbsnews @tesla sends gps location, what the driver is doing, video of the driver sleeping &amp; slowly pu… https://t.co/chludladyf',
#  '@raffaeru @tesla_truth woot ... what is rapidgate ??',
#  '@tesla_truth jack just cares about alibaba. elon cares about us.',
#  'rt @evdefender: tesla flashback:\n\n2016: fake solar roof unveiling\n"that\'s what it looked like before.  now that\'s all solar"\n\n2019: deposit…',
#  '@jrandlewis @corporacallosa @cbsnews the problem is that while it can do a better job than humans in some areas, it… https://t.co/u9gfeb8zqb',
#  'rt @tyrenepamstein: @casey @tesla yup. it’s a beauty. 😉👊🏻 #yang2020 #yanggang #miniandrew https://t.co/7dkjehcmnu',
#  "tesla model 3 was uk's no 3-selling car in august https://t.co/xatihycznw",
#  'i want a tesla',
#  '@abhicantdraw the consensus is that the debate was part of a deal to get tesla a sales tax rebate on their evs. the… https://t.co/sbeybmhg7x',
#  'but, i was assured this only happened once and nobody would be this stupid after that one time!  it says not to do… https://t.co/flhr8ys00r',
#  'dear #tesla drivers.... if you’re going to cruise and drive at least wear shades or!!!! put tint on your windows duh!',
#  'u.s. household sentiment dropped in august to the lowest level since january, as monetary and trade policies height… https://t.co/fn6ked6jej',
#  'rt @evankirstel: don’t sleep and drive #tesla #boston https://t.co/tlbosgz4yl',
#  '@teslaownerssv just seen this on the news... tesla owners, please stop doing this!!!!',
#  'rt @inactionnever: yet another tesla driver was spotted asleep on the highway.😳\n\n https://t.co/zrwqy1uuey',
#  '@casey @tesla i prefer my gas engine, but at least the external aesthetic is there.',
#  '@cullmanec are we going to be seeing a tesla supercharger in cullman in the future? i think the cullman shopping ce… https://t.co/xzbiixs4yx',
#  'rt @vievararosel: @podcast_spain there were no computers 💻 back then. i’ll probably be a scholar 📚 for doing a lot of studying but never an…',
#  '@azsweetheart013 @tesla years away from r word - be positive !!! in a good way',
#  'good company, eh @socialmatt? #wrx #tesla https://t.co/8zgvvakovv',
#  '@drewphilips_ yo can i borrow ur tesla my car broke down and i need to go to school',
#  "rt @tesla: our model x towed a plane once and now we're in the 2020 guinness world records book.\n\nso…how's your day going? https://t.co/mtf…",
#  'rt @reuters: california highway barrier not repaired before fatal tesla crash https://t.co/gpi8mryou7 https://t.co/qfchm4twpd',
#  'me: *a dead woman walking, saying my sweet goodbyes on twitter*\n\n.@humbleteej: you hate to see it. \nbut atleast now… https://t.co/ctkpssbby3',
#  "@zackamen @elonmusk @tesla a bumper to bumper warranty that doesn't cover the bumper.",
#  '@alterviggo @tesla @elonmusk the issue is market isn’t giving insane valuation to volkswagen on the basis of this c… https://t.co/zh8mebztj0',
#  'so i have to stay awake in a self driving tesla? what’s the point then ?',
#  '@ndjokofan @djokernole @novakfanclub @usopen thanks for sharing 😊',
#  "@model3owners @tesla what will happen to the ones don't have the speakers installed? my tm3 was built in nov. 2018.",
#  'rt @ricfulop: 1/ new chemistry breakthrough just published by jeff dahn.  @tesla lead battery researcher.  1m vehicle miles, 795wh/l, with…',
#  'rt @tesla_truth: john carmack, the legendary game developer, loves his tesla p100d\n\nlisten to what he has to say: https://t.co/2311mtd8im',
#  'tesla researcher says new battery could last one million miles https://t.co/aksgdrdsnk',
#  'rt @mortchad: whenever i come across this @tesla roadster vid i have to tweet it out. so much dopeness that it can’t be quantified!!!  http…',
#  '@strivenb @tesla_truth @insideevs @elonmusk default the setting to the arguably safer "disengage all on override",… https://t.co/xohq9x4yj6',
#  "that's funny.\n\ncc: @electrekco @insideevs @greencarreports @cleantechnica @tesla @thetweetofgod @vw https://t.co/kdlsauvvkc",
#  '“elon, listen to me you have to fire a tesla at these coordinates on this exact day or we’re all doomed!” https://t.co/z5eey7hhmx',
#  '@scottbuscemi @scot_work @elonmusk @tesla what happens afterwards?',
#  '@qtrresearch @billybernowich @halftimereport @scottwapnercnbc the perfect time to hand the baton would be when the… https://t.co/qy3dmvf87k',
#  'rt @model3owners: i’m starting a “co-pilot” program to teach new tesla s/x/3 owners the ins and outs of using their cars, charging and auto…',
#  'tesla drivers are not woke https://t.co/ev8ijzqb31 #humor',
#  '@w_moorhouse @tesla_truth exactly!',
#  '@silentman08 @schristakos @darkmnemonic @real_john_d @dodge at 310 miles range per charge, i assure you that demon… https://t.co/xopkyyt6f8',
#  'with 909,330 units sold in 2018, the ford f series is the real tesla killer https://t.co/inenmavhwn',
#  '@elonsbrain @tesla_truth yeah, demand will be high. just like etron, taycan, etc.',
#  'please give me a tesla @elonmusk',
#  'while @tesla cars are known for their autopilot function, the company expects drivers to be fully alert at all time… https://t.co/uihqvdfovl',
#  'https://t.co/lpcfmbqvf5 tesla roadster repairs medlock &amp; sons in seattle https://t.co/lpcfmbqvf5 https://t.co/wciod0hfj9',
#  '@tesla_truth they can suck my cucumber 🥒',
#  'tesla officially launches in iceland - electrek https://t.co/a53rlpv6kd',
#  '@ptiofficial bring tesla to pakistan as they are pioneer in the technology.',
#  '@motortrend @vw the tesla model 3 is selling like crazy even with expired tax incentives. americans want compact el… https://t.co/dycpynih0j',
#  '@puncherpillow @quodsemper @elonmusk @tesla @spacex the meme name came from the most popular meme at the time when… https://t.co/gkquyceab2',
#  '@teslaforthe_win @neilsmallwood oh they’re watching really really close. a 2 million barrel a day oversupply crashe… https://t.co/wnon2lveme',
#  'rt @andendall: reason #568 why tesla operates in a parallel (far more intelligent) universe from all other manufacturers https://t.co/paw7i…',
#  'any vague time frame for which we can expect to hear about a tesla pickup truck reveal party @elonmusk?',
#  'rt @goldentouch73: @kirillklip @arikring @amongstwits @hanslak @ecowarriorss @amazingchevvolt @marcvegan @totalrecoverys1 @thenergynet @jac…',
#  'rt @boston25: man says driver was asleep at the wheel of tesla on mass. pike https://t.co/zeiwxdbybu',
#  "rt @leorules1: here's the supposed tesla car winner, i'm sure he was vetted too! take a look at the tweets he posts. billy doesn't seem to…",
#  '@fettucinecapone @gerberkawasaki @jason @tesla i hear that. makes sense.',
#  "@daniel_knauf isn't this why we want self-driving cars? at what point is not paying attention to a self-driving car… https://t.co/1atvyzevg9",
#  '.@tesla i just saw another driver sleeping on the news. couldn’t you install an “are you still driving alert?” like… https://t.co/fvqoixl8yo',
#  'rt @teslany: “16.7 km long cable will be fully connected on september 10 – tesla gigafactory 3”—wuwa 🏣⚡️ https://t.co/hpanf3jdoj $tsla\nwalk…',
#  'nbc news does a story on driver in tesla sleeping while car is on autopilot going 55 mph on freeway and telling you… https://t.co/oj0khnvxd1',
#  'rt @angelndevil2: @tesla_truth @jonbryant421 to be fair he quoted herbert diess vw’s brand ambassador on this. https://t.co/jynzlyirww',
#  'tesla gets tax break in china as gigafactory 3 in shanghai continues construction https://t.co/tzntlnhg7p',
#  'i need that lambo urus in off white and a tesla and throw in a wraith 🥺 https://t.co/zq769tk4is',
#  '@dakrandall hey randall, i work for univision. would you let us air your video about tesla car on tv and our social media platforms?',
#  '@webdriverg @tesla_truth could be a "one more thing" at the pickup event but my guess is 2020',
#  'rt @barbarajdurkin: @csfc67 @sideen_dan @r11rt @aoecoin @drwaheeduddin @jonlesage4 @bosverker @jaggermickoz @edavidan @cadlam @gogetsmartho…',
#  '@tesla @elonmusk hey dude. our solar stopped working july 1 . we were not made aware of it until last week of augus… https://t.co/sq28tjxgoc',
#  'rt @bittybitbit86: i predict an increase of road head that correlates to an increase of tesla sales.',
#  '@tesla_truth thank goodness for early adopters',
#  'rt @webroot: cybercriminals know where to find important information on your device and how to use it. this episode of the hacker files exp…',
#  'rt @alpefley: video appears to show tesla driver asleep in moving car \u2066@cbs12\u2069  https://https://t.co/9jbztjs6gb',
#  '@budda @vroom101 @motonutjob one of these bad boys was the winner of the most negative equity ever award in my car… https://t.co/bfc8tqka4g',
#  '@tesla_truth @realcbont @insideevs @elonmusk yes, as seen in the video, risk of user confusion could be quite high… https://t.co/3tkgmbi0fp',
#  '@mobinfiltrator @hamiltonpolice i always hated seeing. “mud street” as i passsd the tesla exit. :)',
#  '@6abc isn’t that what tesla’s are for? #serious',
#  '@tesla @tesla when self driving eb? (electric bike). https://t.co/rvzwleo8th',
#  'rt @business: porsche unveils its first-ever electric car in its battle to steal a market that tesla built https://t.co/ge8lahbkzt',
#  'they have lots of disposable income there we saw many of the electric tesla cars. but they were all visiting the mc… https://t.co/4ohqqefyvo',
#  'rt @lauraharrisnbc5: snooze control 🚘 💤 \n\ntesla driver asleep behind wheel on mass. turnpike | a driver in massachusetts saw a motorist in…',
#  'video appears to show tesla driver ‘literally asleep at the\xa0wheel’ https://t.co/ffoawbnipa https://t.co/mzynzl9l52',
#  '@comma_ai lane keeping with tacc? yes tesla’s system does this quite well. didn’t see anything in that video that m… https://t.co/tfecrepmnz',
#  '@khalilamar @bonnienorman @elonmusk @dirtytesla @kristennetten @tesla_truth @28delayslater omg ice cream truck mode!!!!!!!!!',
#  "@jcoviedo6 @trumpery45 personally i don't think it works.\n\nwhen tesla was geofencing autopilot, enterprising people… https://t.co/ohwxkykc4u",
#  '@chrisjcav @elonmusk @tesla they did take things... i have it set to auto-lock. the last software update turned tha… https://t.co/zulssgphzz',
#  'more drivers have been spotted asleep at the wheel as their teslas speed down the highway on autopilot https://t.co/9bqqqmmret',
#  'watch tesla drivers apparently asleep at the wheel, renewing autopilot safety questions https://t.co/waiha1q8pe https://t.co/tgo7gmdsl5',
#  'tesla factory tilburg netherlands covered in solar panels https://t.co/5kug5vvrtv',
#  'elon musk: tesla pickup will arrive later than expected - hypertext\n\rhttps://t.co/dxqepptvsi',
#  'san francisco’s most expensive home takes price cut https://t.co/flxxlraoqp https://t.co/r5heewjk2m',
#  '@comma_ai @tesla @waymo so, only one is actually focused on driving?',
#  '@thesmokingtire @thosedrones holy shit, you’re right! although it’s exclusive to the tesla 3. model s and x do come… https://t.co/yfpfkd7qvx',
#  '@vwgroup the #vwid3 needs to be sold in us! @ford doing well to educate public about #evs in extreme cold! the #bev… https://t.co/kdleytjmwh',
#  'rt @samjulien: just drove a @tesla for the first time thanks to @chrisoncode.\n\nwhat have i done.',
#  '@tesla #models does what #taycant. (thank you @sega circa ‘96) https://t.co/vmpxyrnuld',
#  '@cbsnews sounds like tesla needs to put a "deadman" switch in their cars.',
#  "for the last time: you cannot use tesla's autopilot for naptime https://t.co/kyaeu9ftq2",
#  'rt @tesla: {\\__/}            {\\__/}\n( • . •)         (• - • )\n/ &gt;  👶       / &gt; &lt; \\ \nbaby?        no\n\n{\\__/}            {\\__/}\n( •_•)      ✨…',
#  'finally took pics of the scratches and it’s not like horrible but also... it’s a 2 week old tesla fuck you https://t.co/fson7dpiiz',
#  'rt @vivvchy: tesla powerpack battery project hawaii https://t.co/ifm6ups5tz',
#  '@gheader22 like it or not there is innovation there but not a buy for apple per se. elon leading apple - first get tesla in order.',
#  'if you are having a difficult time convincing a spouse to go tesla; suggest that with having a few friends buy a te… https://t.co/cillqq79z1',
#  "rt @firstsquawk: tesla applies for `ga5' permit with city of fremont, california\n\n- suggests planning new assembly line",
#  "rt @issamahmed: mighty impressive from what i've seen and read. porsche has brought all its engineering muscle to bear and i don't see why…",
#  'watch tesla drivers apparently asleep at the wheel, renewing autopilot safety\xa0questions https://t.co/i1eulb3kzy https://t.co/jiuwehdadr',
#  '@alterviggo @tesla @elonmusk german to engish translation never ceases to amaze.',
#  'rt @financialpopper: @wallstcynic it is one thing to miss a morning of work because your #tesla has to reboot, what happens to you when #ne…',
#  'rt @mrnikolatsla: @dakrandall people fall asleep behind the wheel, it’s a thing that happens. when it’s not a tesla, you have no opportunit…',
#  '@brianbrackeen @jason @tesla anything @jason says should be looked at... and i am a jason',
#  "@mytsla @bloodsportcap @tesla @teslasupport that's for the falcon wing doors, not the driver door.",
#  '@fakecarlsagan @tesla_truth a full load, 80,000 lbs, of batteries could be 30 mwh using upcoming battery tech. one… https://t.co/ack0womxge',
#  'rt @sueinphilly: a nikola tesla/trump connection\naccording to the declassified files, dr. john g. trump (an uncle) reported that his analys…',
#  'rt @janeidyeve: @elonmusk ♡ \nelon, maybe you/@tesla can help the people in the bahamas affected by hurricane dorian, their power grid was c…',
#  '@marktsu18 self-driving tesla will do less harm than a sleeping speak of the house.',
#  '@scot_work @orthereaboot i visited a service center recently when i was considering purchasing a tesla. it was a gh… https://t.co/bkf40ubri2',
#  "tesla model y will awaken elon musk's 'alien dreadnaught' factory https://t.co/tkc850x2p2",
#  '@alterviggo @tesla @elonmusk .@vwgroup_de ceo herbert diess is well intentioned, but the time has come "to walk the… https://t.co/dgdtyeje5e',
#  '@brianbrackeen @gerberkawasaki @jason @tesla @jason has a great point here. i camped out in front of the palo alto… https://t.co/h0jn7hlcnh',
#  '@fettucinecapone @brianbrackeen @gerberkawasaki @jason @tesla your common sense has no place on this ridiculous thread.',
#  'there’s an amazing amount of truth to this statement! i seen them drive from two states away to minnesota just so t… https://t.co/odqrs3kzby',
#  'rt @nydailynews: see it: a motorist got quite the surprise when he noticed the driver and passenger in the tesla next to him on the massach…',
#  '@scottbuscemi @elonmusk @tesla another thought is if it’s been to a service center recently. each time i’ve been th… https://t.co/7byvcdwb2y',
#  '@irrefutablesub1 @alterviggo @tesla @elonmusk i’ll take tesla’s death rate over any other vehicle.',
#  'while #tesla was still debating what kind of tent they would get #porsche has arleady finished a 30min factory vide… https://t.co/e2yivrtpas',
#  'tesla summon feature keeps getting smarter. eventually you will be able to summon your tesla from parking lot to wh… https://t.co/1ld20yj3cg',
#  "@alterviggo @tesla @elonmusk that promise was basically a year ago. we're now almost halfway to 2020 from that date… https://t.co/hkenps8ple",
#  "a thief broke into my model 3 last night by simply pressing the door handle. tesla customer service's solution for… https://t.co/zen7cmivvs",
#  'rt @boston25: imagine driving on the mass. pike and seeing the driver next to you asleep. that happened to one man and he spoke with boston…',
#  "@business that's news to most #tesla drivers. they seem to be under the impression that they can watch porn or have… https://t.co/m7f6ecaqtu",
#  "germany's automakers are slow to respond to the tesla challenge https://t.co/b3qqecu8yk",
#  "rt @hyperchangetv: tesla's new gigafactory is poised to begin production just as a 25% automotive import tariff goes into effect $tsla\nhttp…",
#  'rt @jmccloy01: my spouse got a new ride. we named her jules. thanks @elonmusk. #tesla #model3 #spacecoast https://t.co/w39h41hmsa https://t…',
#  'tesla researcher says new battery could last one million miles https://t.co/iszww7b4lx',
#  '@airpodular @liamseskis @elonmusk @tesla @teslasupport problem solved wasn’t that hard',
#  'rt @megazone: @dakrandall as a tesla owner this kind of thing pisses me off.\n\ni love autopilot, but it is driver assistance, not replacemen…',
#  'rt @evankirstel: elon musk: tesla pickup truck pushed back to november https://t.co/wi3bmrcfun',
#  "why i value the intellect of squirrels over most humans. for the last time: you cannot use tesla's autopilot for na… https://t.co/gt4536xq56",
#  'rt @teslaopinion: with longer lasting batteries, tesla #semi seals it’s competitive advantage against diesels, which typically require an e…',
#  'rt @kirillklip: @arikring @jellsmoor @jj_angelus @dotcommodity @totalrecoverys1 @thenergynet @amazingchevvolt @jackthelad1947 @mwt2008 @pro…',
#  'rt @clarkdennism: in typical tesla fashion.. the overall story is turning into a clusterf*%k -update: \n\n“... but nico rosberg won’t be driv…',
#  'ceo to employee salary ratio.\n\nat&amp;t: 366 to 1\nibm:  341 to 1\npaypal: 274 to 1\nintel: 211 to 1\nebay: 143 to 1\nnetfli… https://t.co/2bnnp68ind',
#  'tesla gets tax break in china as gigafactory 3 in shanghai continues construction - https://t.co/js7ftymlq8 #shanghai #china #上海',
#  'publicly traded twitter $twtr, really needs an employee whistleblower to contact @dnc @gop &amp; demand hearings to exp… https://t.co/glztdijyip',
#  '@elonmusk use @tesla accelerometer vibration data with image data to predict and determine smoothest route along a… https://t.co/fwpuq43t1m',
#  'rt @maggiejuang1: @mrseanim @insertnameplea @evafoxu @m7797114115 @johnnacrider1 @elonmusk @spacex @28delayslater @kristennetten @renatakon…',
#  '@theastronomized @tesla_truth hahaha \nhey if they ever get ap this could be entertaining.  don’t like the copilot,… https://t.co/hj5jny0sav',
#  '@brianbrackeen @jason @tesla if its not @elonmusk, (which would be awesome!!) who else can it be? #apple',
#  'watch tesla drivers apparently asleep at the wheel, renewing autopilot safety questions https://t.co/edz7m4lmai',
#  'if you have cruise control on your car you basically have a tesla 🤷🏾\u200d♂️',
#  '@samjulien @tesla @chrisoncode so next step is to buy one. 🚘',
#  '@warfighterrblx @respectfulmemes @tesla @save_mii *gets friendzoned* jkjk',
#  'new battery tech has... potential. \n\nhttps://t.co/hkplc20idl',
#  '@tesla how many retweets for a car?',
#  'rt @danbrekke: safety board says chp, caltrans lapses played part in delayed repairs before fatal tesla crash https://t.co/usnbx4mvyv via @…',
#  'wouldn’t be surprised if most fud was a long term strategy funded by legacy auto companies because they knew when t… https://t.co/yykjt5ct8l',
#  'rt @teslarati: tesla researcher’s 1 million-mile battery cell breakthrough secures the semi’s longevity\nhttps://t.co/lzqdug2j28',
#  '@elonmusk @tesla i so want a tesla pickup... https://t.co/fxt1h7eaxq',
#  'yo @elonmusk any thoughts on this? this is what is keeping me from considering a tesla. more transparency on this w… https://t.co/7dbrqvytaa',
#  'rt @mosun_sexy: at of annoyance and grumbling i noticed all that was happening and went up to meet my brother in his office, i met him behi…',
#  '@mindstatex nobody sleeps like that and wakes up with a happy neck. more likely they are both dead from plastic off… https://t.co/y7fvalbuii',
#  'rt @vivvchy: tesla powerpack battery project in hornsdale https://t.co/bpwgw9bfcs',
#  'on my way home today i saw a lady driving a tesla - she was holding her phone up to her face, talking on speakerpho… https://t.co/pmopzho5qv',
#  '@yvesremmler @tesla_truth why is it that all these cars have a 70s look?',
#  'iceland population = 340k https://t.co/sq378vkr4w',
#  '@elonmusk @jalopnik @porsche @wikipedia should chance the text to “an autopilot is a system used to control the tra… https://t.co/zrcvic5wpz',
#  '@alterviggo @tesla @elonmusk maybe they plan on buying @tesla',
#  'rt @pulte: jennifer is 36 wks along with a high risk pregnancy.\nshe is wife of a veteran whom is 100% disabled. \njen needs some baby items…',
#  'remember folks, @tesla sells *all* of the cars they build with no summer savings events, no hot summer deals, no ad… https://t.co/qbkekqufue',
#  '@mickeyfactz she look like a man in the face tho so 🤷\u200d♂️',
#  '@tesla_truth and offense is the worse defense',
#  'rt @vincent13031925: tesla researcher’s 1 million-mile battery cell breakthrough secures the semi’s longevity \n\nvia: \u2066@teslarati\u2069 \n\n$tsla #…',
#  'what is so fucking great about tesla’s',
#  '@electrifyam model 3 adds 214 miles of range in ~25 minutes.  what did the taycan add?  still very cool. it’s compe… https://t.co/xsekbxhuma',
#  '@tesla_truth and it will use a key? honestly vw? https://t.co/izoidd9tcb',
#  '@teslamodel3fan @vincent13031925 set up a time of use meter so you will get cheap electricity at night when you cha… https://t.co/1ewnyzkjlf',
#  '@fogdo @tesla cool!',
#  "oops here's another person looking for the missing service app @tesla ceo @elonmusk \nhttps://t.co/zrmb5qyv1q",
#  'so @elonmusk i know you’re busy and all with @tesla @spacex @boringcompany @neuralink but there’s a million weebs b… https://t.co/n5loqeetvq',
#  'rt @1munder: #tesla caused tunguska blast and lit up sky for days\n🧐🤓🧐🤓🧐🤓🧐🤓🧐🤓🧐🤓\nhttps://t.co/wq68v2hlch',
#  'rt @bgrahamdisciple: lots of $tsla model 3 inventory is showing up on their website in many cities.  vast majority is sr.  very few if any…',
#  '@mattly there are normal tesla chargers around that are patrons-only for businesses but the supercharger network is, afaict, 100% public',
#  '@tesla_truth well i won’t be getting the i.d.iot',
#  '@nik0la__tesla chill',
#  'rt @hks55: companies that are guaranteed to go bankrupt \n\n1) softbank \n2) tesla\n3) half the shale industry\n4) ge\n5) ibm',
#  '@tesla_truth the vw seems to be a lot smaller than the tesla - do you know if it has a frunk / what the overall sto… https://t.co/jld1a65pem',
#  'rt @3amart: @peaceloveanie @robbin_young @motherofdogsx2 @tdelovely @hangnfive @cjsmith888 @donaldjtrumpjr @pulte @fosterfriess @realdonald…',
#  '@tesla_truth i’ll give them one thing, not many buttons!',
#  '@casey @tesla one thing all tesla cars are not is beautiful i’m afraid. that’s the one thing they forgot to do, design the outside',
#  'rt @vincent13031925: base on the data from https://t.co/tovqamgynv, 1.46m units of pickup truck had been sold in 1st half of 2019(us). esti…',
#  'waiting on your @tesla  #model3au order? check out our guide on setting up your usb solution!\n@techau @vedaprime… https://t.co/f8vuyq0jo2',
#  'the tesla has auto pilot so it’s fine. maybe the person driving should mind their business https://t.co/mtaykahl7x',
#  '@frankcalvillo3 only if it’s the tesla sign',
#  '@model3owners @scottwww @tesla let that be selected by tesla itself .. .. problem solved',
#  'tesla megapack utility scale energy storage system https://t.co/wvpkqi6wx8',
#  'rt @tesla_truth: tesla model 3 is now the #3 best selling car in the uk 🇬🇧\n\nnot number 3 electric car. number 3 car, at any price. \n\nsales…',
#  '@tomjohn266 @tesla @elonmusk see my earlier posts on musk.',
#  '@kristennetten @romn8tr @tesla_truth omg, nice to meet a fellow fan. i love young frankenstein! https://t.co/ak0etpy5lq',
#  'i break neck for tesla’s the same way guys do when they see a fat ass 😯 https://t.co/fnmeao9h4o',
#  'rt @keithkeller: "dez video challenge"\n((melbourne special edition))\n\nanother fantastic meet up \nwith @musiccomposer1\n\n#dezvideochallenge\n@…',
#  '‘bizarre’ video shows tesla driver apparently asleep on mass pike https://t.co/kczfo1yvmc',
#  'tesla researcher says new battery could last one million miles https://t.co/vnxjbzkxis',
#  'so wait, if a driver falls asleep at the wheel of a tesla, which then saves your ass by driving for your in almost… https://t.co/qsnhodwee6',
#  'and me dwayne antonio riojas commander of the united states military deputy director of the central intelligence  a… https://t.co/ys6dc7h4gd',
#  '@vincent13031925 @elonmusk @tesla with tesla officially in ice-land, ice will go away sooner or later👍',
#  '@tesla_truth 😂 love it',
#  '@mattstert3 @savedtesla @icannot_enough @realchaozhou @tesla that above rendering is only for phase 1. the final bu… https://t.co/xx0tqrapdw',
#  "when push comes to shove...if it means tesla is able to help save the planet because of its vehicles, i'd happily f… https://t.co/fylqk14pqa",
#  '@ryansnotahacker how?\nare we taxing siri? the coffee maker? tesla? roomba?\n\nlolol',
#  'norway’s electric car miracle is a smug national fraud built on subsidizing rich people with teslas https://t.co/dyrxoe0yax',
#  'safety board says chp, caltrans lapses played part in delayed repairs before fatal tesla crash https://t.co/usnbx4mvyv via @kqednews',
#  '@getjeda @fuhklanny @sandisk he needs to use that drive because it’s supported by sentryview app. extension should… https://t.co/oxqandurbn',
#  "rt @aaronglz23: @tesla_truth hyundai kona 64 - 258 miles epa and it's an suv. vw group don't know how to make an ev",
#  'rt @kiwiev: a long-overdue electric car update is here!\nclick to watch: https://t.co/qskw3agbrx\n🇺🇸\nin this video: i discover walmart is act…',
#  '@hmeisler isn’t tesla part of the industrial companies?',
#  '@jason @qtrresearch @billybernowich @halftimereport @scottwapnercnbc tesla as a company is falling apart. other nam… https://t.co/6qivaha1pf',
#  'rt @humorandanimals: this is hazel, she has an outline of herself on her back\n(hound_with_a_hound_tattoo ig) https://t.co/rq33vukw3d',
#  'pretty sure "an automaker, only less capital efficient" is something nobody was asking for. \n\nyes, tesla is more th… https://t.co/e2lapiuwii',
#  'i had a guy whip a tesla into chick today and i asked him how you open the doors and he let me explore it &amp;&amp; 🤩🥵',
#  '@coco_gh the way i’m mad ehhh',
#  "rt @gordonbrianr: “well, they've done it. with 100 miles of reasonably real-world range for under $9,000, renault has accomplished somethin…",
#  'watch tesla drivers apparently asleep at the wheel, renewing autopilot safety questions \nhttps://t.co/e1juiwjleh… https://t.co/kre52rnd1l',
#  "i'm curious how the route that tesla's training data comes up with compares to the one that i drive",
#  'video shows motorist asleep behind wheel of self-driving tesla - nbc news this is not the first time i’ve seen phot… https://t.co/cabipkjmks',
#  '1,108 clinical hours 20 + comps on diagnostic studies mastering 2 different mri machines a ge 1.5 tesla a 1.5 tesla… https://t.co/dgd3ujmgqp',
#  'would totally just geek out if we can see the "augmented vision" to get a sense of what @tesla nn / ap computer is thinking!',
#  "this story you're seeing with the tesla driving on the highway while its driver is... https://t.co/5lxnvoahfs",
#  'no glass roof. maybe someone has the size specs https://t.co/aalc24im8h',
#  "@scottmbrownlee @tesla it's free on the model x :)",
#  '@teslaagnostic if he follows tesla charts next, we may see something like this go down ( stated with my tongue firm… https://t.co/qiprvsvwgh',
#  '@robertnricher @ketoaurelius @getongab it’s a thing. imagine if 5 or 20\nfords spontaneoudly combusted. tesla’s are… https://t.co/9yv0axl2j8',
#  'rt @model3owners: breaking: @tesla technician informs me that all #model3s built since 9/1 have a pedestrian warning speaker installed that…',
#  '@netflixandlamp @fistenergy the banks and brokerage firms $$$$$$ \nthey make money up, down, refi, etc \n\nif interest… https://t.co/jxords0lwn',
#  "@tesla @seanholung 9 tesla's on a truck last thursday... like a pride of lions, any close group of more than 5 tesl… https://t.co/f8i6fwasjz",
#  'rt @gbut: @caliberarms @blacksocialists tesla wanted to create an earth-scale power delivery network. the problem was it would be hard to c…',
#  "@alterviggo @tesla @elonmusk brother, that's why i don't get drunk (will do when teslaquilla is available, tho)...… https://t.co/mo2rlx11ve",
#  'rt @forbes: the secret of tesla’s success is not selling cars. it’s being able to anticipate the future https://t.co/y7t9bi2lbl https://t.c…',
#  '@alterviggo @tesla @elonmusk do it.',
#  '@tweetertweaker so you mean tesla is far more efficient in their use of capital? \n\ni agree.',
#  "@trader51 @alterviggo @macklinhogan @tesla yes, they reduced range on some older s85's",
#  '@keithparkers @tesla no such thing as a free lunch.',
#  'cars: these are the cars that owners keep the longest https://t.co/ihzco2i6el @portal4nws #cars #portal4news https://t.co/29y7etusv7',
#  'tesla truck reveal got pushed back to fucking november fuck musk lives https://t.co/pqp1ngpb7j',
#  '@trumpery45 @greentheonly the simple fact is no one has died in a crash where super cruise has been engaged whereas… https://t.co/51sfx363xv',
#  '@6abc alternative headline: tesla saves sleeping man’s life. \n\never wonder why we never see video of anyone asleep… https://t.co/tr5fcxpx3r',
#  'rt @mari1967: @bullsbearsfbn @jonathanhoenig @kristinaparts @robertwolf32 @stephenmoore @garykaltbaum all i can say is eek!... (tesla drive…',
#  'tesla would be too much car for me, i am 70, but need a small car since mine is on it’s last legs. any help in that… https://t.co/i2gaiuiwsh',
#  '@evadoptiontweet @tesla agreed, in eu, not sure about north america though.  chevy bolt, tesla, nissan all have a p… https://t.co/uyosktmbpr',
#  "@talkinknowledge @business @ford @teamchevy @dodge @fordmustang @corvetteracing @tesla @richzeoli mine's not an opi… https://t.co/9tanz0wnff",
#  'rt @blkmdl3: driving a @tesla is dangerous, you will never want to drive anything else ever again! @elonmusk https://t.co/uissnfumsb',
#  'rt @brianbrackeen: i worked at apple and owe much of my success to it, &amp; @jason ‘s criticism here is 100% correct. apple’s financial succes…',
#  "the world's most important electric car is launching now, and it's not a porsche or tesla https://t.co/jkonnivzli",
#  'rt @nbcbayarea: video captures a tesla driver asleep behind the wheel on the massachusetts turnpike. https://t.co/l7cy9dlmzd',
#  'rt @heyk1967: tesla driver caught fast asleep while driving down the highway 🙄🙄😬😬🧐🧐i don’t think that is what auto pilot  is intended for !…',
#  '@fresnobee “obviously a tesla autopilot failure” - coming up next on cnbc',
#  'tesla launches its own auto insurance; toyota-progressive partner on opt-in driving data offer $tslaq https://t.co/xpu5zlnkab',
#  '@realcbont @strivenb @insideevs @elonmusk no, using the wheel to disengage just one makes more sense. otherwise the… https://t.co/7lavg5wacq',
#  '@vincent13031925 @markchica me too, i can’t see so many retweets because i’m blocked lol',
#  'rt @hybridecon: $tslaq @tesla_truth in case you missed it, the real scandal is all the legacy auto execs going to jail..   \n\nhiroto saikawa…',
#  '@clarkdennism thank tesla for that. if it wasn’t for tesla, evs wouldn’t be sexy, vw and porsche wouldn’t have buil… https://t.co/v6aoi9yukg',
#  'just f__king nuts !!!!!!!!!!!!!!! \n\ndakota randall was driving on the massachusetts turnpike and noticed both the d… https://t.co/u3hl956afx',
#  'as more and more tourists and residents drive electric vehicles, businesses like caesars and tesla are installing n… https://t.co/c6kczevb8a',
#  '@teslamodel3fan @vincent13031925 maybe check out if you could get a permit for a small wind turbine',
#  '@tesla_truth this looks very nice compared to the @porsche. i would take this interior over the tyacans any day of the week.',
#  '@jtseo9 "..boot stomp tesla into the ground."\nreally? porsche understands the market. the market is for wealthy men… https://t.co/s6e5tvoijb',
#  "tesla battery researcher unveils new cell that could last 1 million miles in 'robot taxis' - electrek https://t.co/uhcfka2oh0",
#  "wow, i think i need to follow gerard detourbet's work. $8k for a new electric vehicle is something remarkable. https://t.co/jyoed0r61p",
#  'how many bitches can we fit in the tesla?',
#  '@tesla_truth dang i thought i had his aum chart.',
#  '@talkinknowledge @business @ford @teamchevy @dodge @fordmustang @corvetteracing @tesla @richzeoli enjoying your desperation here.',
#  'rt @teslarati: tesla gigafactory 3 expands with phase 2 construction, ongoing 24/7 shifts\nhttps://t.co/jfadb3w7ns',
#  'i just joined this amazing challenge that’s changing my life. you can even win a tesla. well i’m gonna win it, but… https://t.co/hnwrhzm0l7',
#  '@iayori @brianbrackeen @jason @tesla @apple who is terrified to criticize tim?',
#  'rt @luxury: world debut: the porsche taycan turbo is $150,000 worth of trouble for tesla https://t.co/mxihb4nr3r',
#  '@talkinknowledge @business @ford @teamchevy @dodge @fordmustang @corvetteracing @chevy @tesla bevs have 100x fewer… https://t.co/oyha26vvzs',
#  '@disctechwizard @vincent13031925 @tesla_truth great point!',
#  "rt @neontaster: doesn't say how the story ended, but what you do in that situation is get in front of the tesla and start slowing down unti…",
#  'u.s. regulators take aim at tesla over model 3 safety claims https://t.co/1av7asq26g https://t.co/eiappkyhs5',
#  "i will have a tesla in this life time. its literally my dream car. that and a 3 cartier love bracelets exactly. i'm… https://t.co/bcf195na2v",
#  'if you tell yourself your handwriting is bad because you’re smart, what else do you believe. having no wrist contro… https://t.co/szlptg1ikt',
#  'he got a tesla https://t.co/x5o7djbvep',
#  '@elonmusk my tesla mcu died needs a replacement! this is a known problem they are faulty. why won’t tesla take resp… https://t.co/2z2xej5zw1',
#  'volkswagen id.3 is almost an electric golf – and cheaper than tesla model 3 | trusted reviews https://t.co/eg7ploogjr',
#  '#fox61ct #driverassist  #vehicles will be guided by #satellites in #space the #technology is still in the #learning… https://t.co/a6bah2dnqo',
#  '@elderspook @electrifyam @clarkdennism not only tesla, ea also offered free charging.',
#  "rt @scottbuscemi: a thief broke into my model 3 last night by simply pressing the door handle. tesla customer service's solution for invest…",
#  'rt @mosun_sexy: so today a guy came for a job interview at my brothers company, reviewing his cv man was fit for the job, interview time wa…',
#  'first ride in a tesla!!  #1hotel #southbeach',
#  '@forbes tesla is speculating on the stock market?',
#  '@runthejoule @tesla @elonmusk so you were just in drive and foot on the paddle and it stopped all by itself?',
#  'rt @djdura: is there a bug or an extra feature that the "service" choice is gone from the tesla app? @elonmusk',
#  '$tsla\'s bumper-to-bumper to warranty* doesn\'t actually include the bumper\n\n*"covers the repair or replacement neces… https://t.co/jyj79tzwdh',
#  'wework has $37 billion in lease obligations at the end of 2018\n\nwhat happens if the economy goes south and a lot of… https://t.co/b26rj9jv7o',
#  "rt @rtehrani: the world's most important electric car is launching now, and it's not a porsche or tesla https://t.co/semifxgga9 https://t.c…",
#  '@casey @tesla gotta put some rims and tints on that tesla',
# ...
#  "rt @runthejoule: my #tesla avoided a crash w/ a bicyclist and autopilot wasn't even turned on.  it braked entirely on its own.  thx to the…",
#  '@tesla_truth look at the i.d. buzz \n\nthose floor tracks for the front seats?  musical chairs while you drive? https://t.co/vrdcjzjnle',
#  'just drive a non tesla car for the first time in almost a year and that was the worst experience of my life',
#  "rt @vivvchy: production line at tesla's gigafactory fremont https://t.co/8p3zolu3ky",
#  "@mytsla @lorakolodny @dowdedward @cnbctech how is blatently overriding safety features tesla's fault.",
#  'my next car will be a tesla, i promise',
#  'rt @pulte: yes, we are the team (formerly called followers) giving away a tesla on the internet 😊 more giveaways soon.  video: https://t.co…',
#  '@elonmusk @erdayastronaut @ivanescobosa @djsnm @kevinkling12 @spacexcentric @elonmusk , the piles of trash on the r… https://t.co/kdugywgyyt',
#  'rt @amlivemon: automakers margins are tight, less than 6%... which is why they mass produce. tesla cannot and they lose $11,000 per car...…',
#  'rt @phenomenalpoto: forgetting someone, @jason? \n\nhow about someone that commutes on that same g650.\n\nsomeone that said they would never ra…',
#  '@tesla_truth 216 miles highway.\nno supercharger network.\nawd / performance / ota?\nbasic highway driving assist.\npro… https://t.co/lqfazyh0xt',
#  '@tomi @jamesbardolph ok. may i ask why not? is it the simple fact that tesla fires are *way* less common on an adju… https://t.co/xs1qamqckt',
#  'rt @jppmorgann: another one of these videos i suspect are just staged tesla guerilla marketing videos.... https://t.co/ml9qykx14b',
#  '@tonycrisostomo @tesla_truth not really, m3 starts from about 50k eur. be careful when comparing eu (includes vat) with us prices',
#  '@tesla so how come it is so difficult to get a tow package approved by tesla in the us?',
#  'as we’re picking up our rental car which is a mini van the guys behind us are picking up a tesla ive never felt more poor',
#  "@teslord1 @evautonomy @tesla we're at ~20% electric on new vehicle purchases, without the most popular car in europ… https://t.co/4gvnqu05lf",
#  'hey alexa hey alexa how many bitches can i fit ina tesla',
#  'rt @danahull: newish from me: first reference i’ve seen to “ga5” : tesla permit application hints at another fremont assembly line - bloomb…',
#  "@motonutjob the ugliest cars ever built, now available in pepto-bismol pink.  and what's up with the tesla drivers… https://t.co/b6dykwh4e7",
#  'my uber is a tesla im too excited lmao',
#  '@hastybasher0624 @breaking911 tesla ran into a firetruck in ca......',
#  '@tesla_truth overall, it’s not a bad car, but:\nm3 = iphone; id3 = nokia n97 - a lot of people in 🇪🇺 / 🇩🇪 don’t unde… https://t.co/o6m5z5ycli',
#  'beach buggy racing is a lot more fun with a game controller! https://t.co/nhykivwwjn',
#  'construction update video from #gigafactory3 in shanghai https://t.co/bqt8cn87qe https://t.co/wyhgzpmpm1',
#  'musk says tesla pickup debut pushed to november - tesla motors club https://t.co/wpibzofeba',
#  'rt @nbcnews: video shows motorist asleep behind wheel of self-driving tesla. https://t.co/snntxgddyd',
#  '@brianbrackeen @gerberkawasaki @jason @tesla rubbish',
#  '@figoneloson i’m sure that’s what you did. smh 🤨 do you even work?',
#  'rt @_rebelbynaturex: y’all be weird on curious cat. all you do is ask opinions on yourselves anonymously, ask me real questions about leagu…',
#  '[like a boss] https://t.co/xwq9busxkz via @youtube',
#  '@scottbuscemi @elonmusk @tesla tesla is a joke. the only thing they’re good for is kicking real car manufacturers into action.',
#  'rt @robotbeat: @sustainerr @anshid_np @tesla_truth tesla is able to do it instead by cooling the cables (and using aluminum, which has ~hal…',
#  'rt @sustainable2050: in just 2 years, volkswagen’s zwickau production site will become europe’s largest electric car manufacturing plant wi…',
#  '@marks22 @bonnienorman they do a similar thing at some chargers in china. bays don\'t "open up" till a tesla is there.',
#  "@tesla how i'm trying to be",
#  'rt @nickhintonn: when people hear the word electricity, most think of thomas edison. some says there’s a reason for this. tesla spent a lot…',
#  '@cbsnews free advertising for @tesla',
#  "@elonmusk are they considering banning the autopilot on tesla's?",
#  "@brettking @tesla @nigelwalsh smoke if you got 'em",
#  'rt @tesla_truth: the greatest mistake tesla haters make is underestimating autopilot\n\nit comes with every tesla, and after you try it once…',
#  "the tesla model 3 'superbottle' easter egg is a fascinating packaging solution https://t.co/brucvy9sw6",
#  'tesla’s battery researcher tests 1-million-mile battery cell https://t.co/ibqgljjvh8 https://t.co/q4fc5zdyw0',
#  'rt @elonmusknewsorg: elon musk: tesla pickup truck pushed back to november  https://t.co/bo43ui4ycr',
#  'rt @b_mcbeardface: a huge reason why @tesla should be available on the #uk’s @motability scheme to help  #disabled drivers. even those who…',
#  'rt @tesla_truth: tesla:\n\nzero emissions to try and stop climate change\n\nremotely controlled air conditioning in case it gets worse https://…',
#  'rt @chiefsdiva69: jen is a high risk pregnancy at 36 wks. \nshe is the wife of a 100% disabled af veteran. \ntesla let her go before she was…',
#  "i didn't realize how broke i was till i drove a tesla lmao",
#  "my #tesla avoided a crash w/ a bicyclist and autopilot wasn't even turned on.  it braked entirely on its own.  thx… https://t.co/t4fxnr63hf",
#  'electrek sucks.  i look forward to “life after tesla” when a car is rated by its character; regardless of being a b… https://t.co/kokqjsjbtd',
#  '@tintdepot this chemistry designation is not proprietary or exclusive to tesla.',
#  '@jason to me, that is a greater game-changer than buying peloton. but.. in the discussion of tesla, yeah.. no. buy them now!',
#  'if there’s no official launch date, it can’t be delayed.\n\nhttps://t.co/3rwiroytwj https://t.co/oe3yzorq7o',
#  'rt @ky_wagner97: how many bitches can we fit in the tesla?',
#  '@tesla’s roadside assistance 👏🏼👏🏼👏🏼 https://t.co/dkx7v9wgfh',
#  "another case of sleeping drivers behind the wheel of a tesla. just because your car has 'autopilot' or driver assis… https://t.co/fv8c9hqklm",
#  'i need a car wash but tesla got they on roadside assistance i’m sold https://t.co/pd8osskkl2',
#  '@alterviggo @tesla @elonmusk not sure why omes keep trying to beat $tsla at their own game...the market for low cos… https://t.co/g13ktzr8zm',
#  '#lifelog\n#facebook\n\nand really tesla?\n\n@darpa care to weigh in seeking to start an #fr https://t.co/90tyn0hqjz',
#  'fuck a tesla need a rarri',
#  'rt @kas_b747: @bullsbearsfbn @garykaltbaum tesla ah, did you notice he was in the passing lane?  but, the b747 i flew was totally able to t…',
#  '@its_prits @tesla @teslajoy @model3owners @sfteslaclub +1 on cabin heat protection',
#  'rt @maggiejuang1: @mrseanim @m7797114115 @darcnos @insertnameplea @evafoxu @johnnacrider1 @elonmusk @spacex @28delayslater @kristennetten @…',
#  "emailed tesla for clarification on fog lights. i was told 100% wouldn't be any sr+ with them so i can't have them y… https://t.co/ilzasoaxuw",
#  "tesla applies for `ga5' permit with city of fremont, california\n\n- suggests planning new assembly line",
#  '@tesla_truth he is so down to earth. 😂😂  ❤️ @elonmusk. jack we create the future with our actions.',
#  'rt @sputnikint: watch: us motorist records tesla driver ‘completely asleep’ while driving \n\n@tesla https://t.co/nryyxgl9bz',
#  '@tesla @chevrolet @dodge @kia @honda @gmc @ford @jeep @toyota to add this feature ensures a life will be saved &amp; pr… https://t.co/5xaj8zlnbb',
#  '@zonephysics so therapeutic to watch',
#  '@thomass32918110 @drcamiloortiz @tesla @elonmusk california asian drivers are unpredictable',
#  '@elonmusk ♡ \nelon, maybe you/@tesla can help the people in the bahamas affected by hurricane dorian, their power gr… https://t.co/qusq2nd8kz',
#  'we want tesla events to drop same time to apple events',
#  '#tesla drivers r the worst',
#  '@brandontroberts @samjulien @tesla @chrisoncode gonna have to agree. your bank account bout to take a hit',
#  '@repthomasmassie that tesla is about 100 times worse for the environment, but whatever helps you sleep at night. buy a bike.',
#  'tesla lowers powerwall 2 price $2,200 in sa virtual power plant deal  https://t.co/8d39llwijt',
#  '@mrseanim @m7797114115 @darcnos @insertnameplea @evafoxu @johnnacrider1 @elonmusk @spacex @28delayslater… https://t.co/9oongj14rf',
#  'rt @fogdo: thank you @tesla for this helpful and cool feature :-) https://t.co/fluy3yfdsl',
#  'rt @teslatunity: @tesla is really taking over my work parking lot. one day i should go around and count but i’d bet it’s at least 20-30 now…',
#  'rt @zerohedge: analyst with $0 price target on tesla says growth story "clearly over" after august delivery estimates https://t.co/ueeklzsy…',
#  'rt @savedtesla: tesla owner credits model 3’s instant acceleration for helping to avoid a crash : "i have never appreciated having an insta…',
#  'abc #worldnewstonight has another video of a #tesla driver on the freeway asleep at the wheel. note, they are never… https://t.co/bzzqakjx32',
#  '@tesla_truth throw some prices on that table...',
#  '#tesla : $tsla sept-9 update #stockmarket technical analysis chart\n\nwatch -&gt; https://t.co/ovyrhclcbg https://t.co/yay4k441kn',
#  'thanks @techloreistaken for the very thorough, unbiased look at the privacy aspect of the @tesla model 3. i persona… https://t.co/jxvwpdarou',
#  'battery breakthrough? https://t.co/kmzhpsij29',
#  '@scottbuscemi @elonmusk @tesla idk there have been so many reports of issues that i just don’t think they’re worth the price',
#  '@scottbuscemi @elonmusk @tesla did they take anything, do you have it set to auto-lock, and do you use “pin to driv… https://t.co/557owiwzpc',
#  'tesla car that crashed and killed driver was running on autopilot, firm says | technology | the guardian\n\n https://t.co/xn3sg4mz1a',
#  'tesla driver looks to be asleep behind the wheel on highway\n\nauto pilot\nasleep at the wheel! https://t.co/cn43yyefxx',
#  'ut oh... nbc news....asleep at the wheel in tesla on mass tpike',
#  '@glorycorinne @tesla yess',
#  'oh yeah! lol! https://t.co/zcacdota1p',
#  '@elonmusk any chance to get the power sport 19’s for the 3p w/ red calipers in the us?  \n\nwould love those with win… https://t.co/4samejy1x0',
#  'rt @lorakolodny: tesla drivers-- apparently asleep at the wheel-- renew autopilot safety questions via @cnbctech https://t.co/a9uvj1tebb (w…',
#  'forgetting someone, @jason? \n\nhow about someone that commutes on that same g650.\n\nsomeone that said they would neve… https://t.co/oftlt0pkk1',
#  '@jordanraanan wow!!! like that’s going to help with our non existent pass rush ...... 🙄.  is there nobody that’s a… https://t.co/e5pmmctskj',
#  'i want a @tesla',
#  '@brianbrackeen @jason @tesla @elonmusk would never sell that early.. apple wishes tesla dumps to atl but that seems doubtful',
#  'tesla driver dies in first fatal crash while using autopilot mode | technology | the guardian\n\n2016 https://t.co/psij4v7jbu',
#  '@elonmusk i currently have a toyota tacoma i use for a daily driver and 4x4 off roading in the colorado mountains.… https://t.co/smg1ghy0wz',
#  '2/2 the state of california is being criticized by the national transportation safety board for not repairing crash… https://t.co/occs4sbfz8',
#  'watch tesla drivers apparently asleep at the wheel, renewing autopilot safety questions \nhttps://t.co/tfvrg7una8',
#  '@m_xalher not a mention of tesla! not a tesla in sight. hmmm',
#  "@tesla_truth i haven't played this game in too long. hopefully the next time i do so will be on a tesla dashboard.",
#  "@elonmusk please bring tesla's to turkey!",
#  '@italianmaster @business @ford @teamchevy @dodge @fordmustang @corvetteracing @tesla @richzeoli reply i’ll be back… https://t.co/cq5vtdvrvc',
#  'i.c.e. = internal combustion engine.\nn.i.c.e. = not internal combustion engine. \nloving our tesla’s, be n.i.c.e. !\n@elonmusk @tesla @evafoxu',
#  'rt @benshooter: now do tesla and elon. https://t.co/ne9nctkz1u',
#  "rt @samjmintz: interesting note from ntsb's tesla crash report today: five other manufacturers have responded to the agency's safety recomm…",
#  '@jakesebah yeah they are reliable. i wanna get a tesla so bad lol',
#  'rt @svilledance: congratulations to our sting of the week sofia ramos and shining star tesla sams for the sept. 6th football game vs everma…',
#  '@zackamen @elonmusk @tesla tesla doesn’t make a profit, and is only surviving quarter to quarter. \n\nif they can’t r… https://t.co/jebk0uyzqq',
#  '@trumpery45 @jcoviedo6 disengaging? really? that does not sound super safe. at least tesla stops (and until the spe… https://t.co/ansouwmhby',
#  'rt @itshovah: this is the tesla winner.. nice. https://t.co/zsg6ns8qqw',
#  '@alterviggo @tesla @elonmusk they probably falsified that tweet too',
#  '@teslabros @tyleryoung1230 @gibstrina @gracieyoung26 @tesla when i showed her other cars i was told to stop obsessi… https://t.co/axvbv3nyjd',
#  'rt @andersonf150: tesla driver looks to be asleep behind the wheel on highway\n\nauto pilot\nasleep at the wheel! https://t.co/cn43yyefxx',
#  'rt @lbox327: if you know the story of nikola tesla \n\nthen here is a story of a man you may not know \n\ngary kildall\n\nthe man who could have…',
#  'newish from me: first reference i’ve seen to “ga5” : tesla permit application hints at another fremont assembly lin… https://t.co/biksmzxewc',
#  '@okdoogl @nimbuswolf @vw .... if the us had that tax, i would almost certainly have a tesla model 3 right now inste… https://t.co/1qw51pbzcz',
#  'rt @vivvchy: tesla powerpack battery project flanders https://t.co/da9swwirbs',
#  '@mattly "destination charging" is a slower charging option that may be restricted to patrons. when i drove a tesla… https://t.co/ytxsnkookj',
#  '@h2oboyboucher @jekhatulan10 @anshid_np @tesla_truth @tesla tesla isn’t doing such a thing, which could be used for… https://t.co/2bhcyxcfve',
#  'rt @cnbctech: watch tesla drivers apparently asleep at the wheel, renewing autopilot safety questions https://t.co/uopkmbblol',
#  'this week, safeeya and inder focus on #tesla new self-driving #cars, #twitter getting hacked, and would you take a… https://t.co/9gcxgjhztq',
#  'rt @paul91701736: this is from may and has been seen here before, but i thought it was time to add it back to the flaming pile that is the…',
#  'rt @teslabros: @jeffalawless @tyleryoung1230 @gibstrina @gracieyoung26 @tesla "honey, did i ever tell you how beautiful you are? \n\ncan i ch…',
#  "@tesla_truth how strange to say that the desk is great...i make furniture for a living...it's not bad but my desks… https://t.co/fjwkuje8vz",
#  "i'm taking my #tesla #modelx to a trade show and super annoyed that i need to pay for electricity to power a monito… https://t.co/le6ajy15km",
#  'watch tesla drivers apparently asleep at the wheel, renewing autopilot safety questions https://t.co/ww7vrctgxu',
#  'rt @elonmusk: changing tesla horn sound to 🐐',
#  'rt @icosanaut: @elonmusk @tesla can you see about putting superchargers in del rio texas or someplace reasonable close like uvalde?',
#  'how many bitches can we fit in the tesla',
#  'rt @twaimz: tracklist for my upcoming album!\n1. get a job\n2. hi i’m rich\n3. did you know i’m rich?\n4. lavender tesla\n5. do you juul? have f…',
#  'rt @dianeraucher: tesla researcher says new battery could last one million miles https://t.co/vnxjbzkxis',
#  '@macklinhogan 4) none of this has has anything to do with why tesla is leading significantly in powertrain efficien… https://t.co/x7kfmomfz5',
#  "@jason @elonmusk @tesla @weworkadam sure it's a shit business model... but did they ever promise profitability? https://t.co/q5rfss4rra",
#  '@vincent13031925 @elonmusk @tesla any e.t.a. for south america?',
#  "rt @forbes: tesla's battery expert has published results on new battery cells that might last 3 or more times as long as current batteries…"]

# %% [markdown]
# ___
# ### Classificando as mensagens na coragem
#
# Esta etapa é manual. Faça a mesma pelo Excel.

# %% [markdown]
# ___
# ### Montando o Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %% [markdown]
# ___
# ### Verificando a performance
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * Montar um dashboard que periodicamente realiza análise de sentimento e visualiza estes dados

# %% [markdown]
# # Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
